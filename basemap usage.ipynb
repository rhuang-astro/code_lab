# %% [markdown]
# # Usage of Basemap
# ## import function
# test1

# %%
print('test')
# Out:
# test

# %% [markdown]
# test2

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt

# %% [markdown]
# ## show me code

# %%
m=Basemap()
m.drawcoastlines()
plt.show()

m=Basemap()
m.shadedrelief()
plt.show()

m=Basemap()
m.drawcoastlines()
m.drawmapboundary(linewidth=0,fill_color='white')
plt.show()
