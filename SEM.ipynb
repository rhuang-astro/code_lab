# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#SEM" data-toc-modified-id="SEM-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>SEM</a></span><ul class="toc-item"><li><span><a href="#prepare" data-toc-modified-id="prepare-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>prepare</a></span></li><li><span><a href="#SEM_AN" data-toc-modified-id="SEM_AN-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>SEM_AN</a></span></li><li><span><a href="#SEM_SC" data-toc-modified-id="SEM_SC-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>SEM_SC</a></span></li><li><span><a href="#SEM_SCP" data-toc-modified-id="SEM_SCP-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>SEM_SCP</a></span><ul class="toc-item"><li><span><a href="#Pkg_1" data-toc-modified-id="Pkg_1-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>Pkg_1</a></span></li><li><span><a href="#PKg_2" data-toc-modified-id="PKg_2-1.4.2"><span class="toc-item-num">1.4.2&nbsp;&nbsp;</span>PKg_2</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # SEM

# %% [markdown]
# ## prepare

# %%
from GCSpy.GCSpy import *
import warnings
#from IPython.core.interactiveshell import InteractiveShell
#InteractiveShell.ast_node_interactivity = "once"
# Out:
# /Users/rhuang/software/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py:886: MatplotlibDeprecationWarning:
# examples.directory is deprecated; in the future, examples will be found relative to the 'datapath' directory.
#   "found relative to the 'datapath' directory.".format(key))

# %%
findfile('/Volumes/rhuang_Passport/HXMT_data/1P','SEM','all')
# Out:
# search SEM in /Volumes/rhuang_Passport/HXMT_data/1P
# ['/Volumes/rhuang_Passport/HXMT_data/1P/Y-1006466008/20170710-0026/HXMT_SEM_AN_20170710-0026_FFFFFF_VV1_1P.FITS',
#  '/Volumes/rhuang_Passport/HXMT_data/1P/Y-1006466008/20170711-0027/HXMT_SEM_TH_20170711-0027_FFFFFF_VV1_1P.FITS',
#  '/Volumes/rhuang_Passport/HXMT_data/1P/Y-1006468152/20170628-0014/HXMT_SEM_TH_20170628-0014_FFFFFF_VV4_1P.FITS',
#  '/Volumes/rhuang_Passport/HXMT_data/1P/Y-1006470248/20170713-0029/HXMT_SEM_TH_20170713-0029_FFFFFF_VV2_1P.FITS',
#  '/Volumes/rhuang_Passport/HXMT_data/1P/Y-1006471064/20170714-0030/HXMT_SEM_TH_20170714-0030_FFFFFF_VV2_1P.FITS',
#  '/Volumes/rhuang_Passport/HXMT_data/1P/Y-1006494760/20170709-0025/HXMT_SEM_TH_20170709-0025_FFFFFF_VV2_1P.FITS',
#  '/Volumes/rhuang_Passport/HXMT_data/1P/Y-1006509208/20170627-0013/HXMT_SEM_SCP_20170627-0013_FFFFFF_VV1_1P.FITS',
#  '/Volumes/rhuang_Passport/HXMT_data/1P/Y-1006512760/20170628-0014/HXMT_SEM_SCP_20170628-0014_FFFFFF_VV1_1P.FITS',
# ...

# %%
SEM_TH_list=findfile('/Volumes/rhuang_Passport/HXMT_data/1P','SEM_TH','all')
SEM_SCP_list=findfile('/Volumes/rhuang_Passport/HXMT_data/1P','SEM_SCP','all')
SEM_AN_list=findfile('/Volumes/rhuang_Passport/HXMT_data/1P','SEM_AN','all')
SEM_SC_list=findfile('/Volumes/rhuang_Passport/HXMT_data/1P','SEM_SC','all')
# Out:
# search SEM_TH in /Volumes/rhuang_Passport/HXMT_data/1P
# search SEM_SCP in /Volumes/rhuang_Passport/HXMT_data/1P
# search SEM_AN in /Volumes/rhuang_Passport/HXMT_data/1P
# search SEM_SC in /Volumes/rhuang_Passport/HXMT_data/1P

# %%
len(SEM_TH_list)
# Out:
# 82

# %%
len(SEM_SCP_list)
# Out:
# 43

# %%
len(SEM_AN_list)
# Out:
# 44

# %%
len(SEM_SC_list)
# Out:
# 86

# %%
SEM_AN='/Volumes/rhuang_Passport/HXMT_data/1P/Y-1006466008/20170710-0026/HXMT_SEM_AN_20170710-0026_FFFFFF_VV1_1P.FITS'
SEM_SCP='/Volumes/rhuang_Passport/HXMT_data/1P/Y-1006526376/20170710-0026/HXMT_SEM_SCP_20170710-0026_FFFFFF_VV1_1P.FITS'
SEM_SC= '/Volumes/rhuang_Passport/HXMT_data/1P/Y-1006526376/20170710-0026/HXMT_SEM_TH_20170710-0026_FFFFFF_VV1_1P.FITS'

# %% [markdown]
# ## SEM_AN

# %%
hdulist = fits.open(SEM_AN)
hdulist
hdulist[0].header
hdulist[1].header
hdulist.close()
# Out:
# [<astropy.io.fits.hdu.image.PrimaryHDU object at 0x1c258bd9b0>, <astropy.io.fits.hdu.table.BinTableHDU object at 0x1c258da6a0>]
# SIMPLE  =                    T
# BITPIX  =                    8 /number of bits per data pixel
# NAXIS   =                    0 /number of data axes
# EXTEND  =                    T /FITS dataset may contain extensions
# TELESCOP= 'HXMT    '           /name of telescope
# INSTRUME= 'SEM     '
# DATLEVEL= '1P      '           /Data Leve in HSDC
# DATAID  = 'ID603   '           /Data Type ID
# CREATOR = 'DPGS    '           /HXMT Data Product General Soft
# ORIGIN  = 'HSDC    '           /HXMT Scientific Data Center
# TIMESYS = 'UTC     '           /Time system
# TSTART  =            174268803 /
# TSTOP   =            174355203 /
# TELAPSE =                86400 / TSTOP - TSTART
# DAY_IND =                  100 /Day count from launch
# DATE    = '0000-00-00T00:00:00'
# XTENSION= 'BINTABLE'           /binary table extension
# ...

# %%
SEM_AN_data = Table.read(SEM_AN)
SEM_AN_data
# Out:
# <Table length=86521>
#    Time    TMY601  TMY602 ... Voltage_Sepc_Sensor Status_E_Spec [2]
#     s                     ...
#   uint32  float64 float64 ...        uint8              uint8
# --------- ------- ------- ... ------------------- -----------------
# 174268743   287.0   215.0 ...                   4            0 .. 0
# 174268744   133.0   291.0 ...                   4            0 .. 0
# 174268745   235.0   313.0 ...                   4            0 .. 0
# 174268746   319.0   195.0 ...                   4            0 .. 0
# 174268747   287.0   215.0 ...                   4            0 .. 0
# 174268748   133.0   291.0 ...                   4            0 .. 0
# 174268749   235.0   313.0 ...                   4            0 .. 0
# 174268750   319.0   195.0 ...                   4            0 .. 0
# 174268751   287.0   215.0 ...                   4            0 .. 0
#       ...     ...     ... ...                 ...               ...
# ...

# %%
for colname in SEM_AN_data.colnames:
    plt.figure(figsize=(8,2))
    plt.plot(SEM_AN_data['Time'],SEM_AN_data[colname],'.')
    plt.title(colname)
    plt.show()
# Out:
# Text(0.5, 1.0, 'Time')
# Text(0.5, 1.0, 'TMY601')
# Text(0.5, 1.0, 'TMY602')
# Text(0.5, 1.0, 'TMY603')
# Text(0.5, 1.0, 'TMY604')
# Text(0.5, 1.0, 'Cnt_Pkg1')
# Text(0.5, 1.0, 'Cnt_Pkg2')
# Text(0.5, 1.0, 'Status_P5V')
# Text(0.5, 1.0, 'Status_P12V')
# Text(0.5, 1.0, 'Flag_Dire_Sensor')
# Text(0.5, 1.0, 'Voltage_Dire_Sensor')
# Text(0.5, 1.0, 'Flag_Spec_Sensor')
# Text(0.5, 1.0, 'Voltage_Sepc_Sensor')
# ...
# Text(0.5, 1.0, 'Status_E_Spec')

# %% [markdown]
# ## SEM_SC

# %%
hdulist = fits.open(SEM_SC)
hdulist
hdulist[0].header
hdulist[1].header
hdulist.close()
# Out:
# [<astropy.io.fits.hdu.image.PrimaryHDU object at 0x1c27690828>, <astropy.io.fits.hdu.table.BinTableHDU object at 0x1c2767bb70>]
# SIMPLE  =                    T
# BITPIX  =                    8 /number of bits per data pixel
# NAXIS   =                    0 /number of data axes
# EXTEND  =                    T /FITS dataset may contain extensions
# TELESCOP= 'HXMT    '           /name of telescope
# INSTRUME= 'SEM     '
# DATLEVEL= '1P      '           /Data Leve in HSDC
# DATAID  = 'ID605   '           /Data Type ID
# CREATOR = 'DPGS    '           /HXMT Data Product General Soft
# ORIGIN  = 'HSDC    '           /HXMT Scientific Data Center
# TIMESYS = 'UTC     '           /Time system
# TSTART  =            174268803 /
# TSTOP   =            174355203 /
# TELAPSE =                86400 / TSTOP - TSTART
# DAY_IND =                  100 /Day count from launch
# DATE    = '0000-00-00T00:00:00'
# XTENSION= 'BINTABLE'           /binary table extension
# ...

# %%
SEM_SC_data = Table.read(SEM_SC)
SEM_SC_data
# Out:
# <Table length=86521>
#     Time         X           Y      ...     Lon         Lat         Alt
#      s           m           m      ...    degree      degree      degree
#   float64      int32       int32    ...    int32       int32       int32
# ----------- ----------- ----------- ... ----------- ----------- -----------
# 174268743.0   751619277 -1288490189 ... -1396379767  -200660872   858993459
# 174268744.0 -1051491988  1093834657 ...  1080349463 -1069258615  1092684193
# 174268745.0   751619277 -2147483648 ...  -673450872  1790829564   858993459
# 174268746.0 -1051491267  1093828227 ...  1080350081 -1069259163  1092684189
# 174268747.0  -429496729  1288490189 ... -1709740581  -366962005 -1717986918
# 174268748.0 -1051490548  1093821796 ...  1080350699 -1069259714  1092684183
# 174268749.0  1503238554   429496730 ...  -562125319  1915899012   858993459
# 174268750.0 -1051489829  1093815364 ...  1080351316 -1069260266  1092684176
# ...

# %%
for colname in SEM_SC_data.colnames:
    plt.figure(figsize=(20,2))
    plt.scatter(SEM_SC_data['Time'],SEM_SC_data[colname],s=0.1)
    plt.title(colname)
    plt.show()
# Out:
# Text(0.5, 1.0, 'Time')
# Text(0.5, 1.0, 'X')
# Text(0.5, 1.0, 'Y')
# Text(0.5, 1.0, 'Z')
# Text(0.5, 1.0, 'Vx')
# Text(0.5, 1.0, 'Vy')
# Text(0.5, 1.0, 'Vz')
# Text(0.5, 1.0, 'Lon')
# Text(0.5, 1.0, 'Lat')
# Text(0.5, 1.0, 'Alt')

# %% [markdown]
# 前500s

# %%
for colname in SEM_SC_data.colnames:
    plt.figure(figsize=(20,2))
    plt.scatter(SEM_SC_data['Time'][:500],SEM_SC_data[colname][:500])
    plt.title(colname)
    plt.show()
# Out:
# Text(0.5, 1.0, 'Time')
# Text(0.5, 1.0, 'X')
# Text(0.5, 1.0, 'Y')
# Text(0.5, 1.0, 'Z')
# Text(0.5, 1.0, 'Vx')
# Text(0.5, 1.0, 'Vy')
# Text(0.5, 1.0, 'Vz')
# Text(0.5, 1.0, 'Lon')
# Text(0.5, 1.0, 'Lat')
# Text(0.5, 1.0, 'Alt')

# %%
(SEM_SC_data["Time"][-1]-SEM_SC_data["Time"][0]) / 60. /60.
# Out:
# 24.033333333333335

# %% [markdown]
# 一个文件 24h

# %% [markdown]
# ## SEM_SCP

# %%
hdulist = fits.open(SEM_SCP)
hdulist
hdulist[0].header
hdulist[1].header
data = hdulist[1].data
hdulist.close()
# Out:
# [<astropy.io.fits.hdu.image.PrimaryHDU object at 0x1c276de2e8>, <astropy.io.fits.hdu.table.BinTableHDU object at 0x1c284c6b70>]
# SIMPLE  =                    T
# BITPIX  =                    8 /number of bits per data pixel
# NAXIS   =                    0 /number of data axes
# EXTEND  =                    T /FITS dataset may contain extensions
# TELESCOP= 'HXMT    '           /name of telescope
# INSTRUME= 'SEM     '
# DATLEVEL= '1P      '           /Data Leve in HSDC
# DATAID  = 'ID602   '           /Data Type ID
# CREATOR = 'DPGS    '           /HXMT Data Product General Soft
# ORIGIN  = 'HSDC    '           /HXMT Scientific Data Center
# TIMESYS = 'UTC     '           /Time system
# TSTART  =            174268803 /
# TSTOP   =            174355203 /
# TELAPSE =                86400 / TSTOP - TSTART
# DAY_IND =                  100 /Day count from launch
# DATE    = '0000-00-00T00:00:00'
# XTENSION= 'BINTABLE'           /binary table extension
# ...

# %%
SEM_SCP_data = Table.read(SEM_SCP)
SEM_SCP_data
# Out:
# <Table length=93600>
#   PKTime  Pkg_1 [62] Pkg_2 [58]
#     s
#   int32     uint8      uint8
# --------- ---------- ----------
# 174265201 105 .. 237   0 .. 189
# 174265202 105 .. 237   0 .. 227
# 174265203 106 .. 237     0 .. 2
# 174265204 106 .. 237    0 .. 27
# 174265205 105 .. 237    0 .. 54
# 174265206 106 .. 237    0 .. 79
# 174265207 105 .. 237   0 .. 118
# 174265208 106 .. 237   0 .. 150
# 174265209 106 .. 237   0 .. 182
#       ...        ...        ...
# 174358791 105 .. 237   0 .. 100
# 174358792 105 .. 237   0 .. 117
# 174358793 105 .. 237   0 .. 159
# 174358794 105 .. 237   0 .. 186
# 174358795 105 .. 237   0 .. 237
# 174358796 105 .. 237   0 .. 253
# 174358797 105 .. 237    0 .. 31
# 174358798 105 .. 237    0 .. 66
# 174358799 105 .. 237   0 .. 108
# 174358800 105 .. 237   0 .. 136

# %%
plt.figure(figsize=(6,20),dpi=144)
for i in range(700):
    a=plt.plot(SEM_SCP_data['Pkg_1'][i]+i*80);

# %%
SEM_SCP_data['Pkg_1']
# Out:
# <Column name='Pkg_1' dtype='uint8' shape=(62,) length=93600>
# 105 .. 237
# 105 .. 237
# 106 .. 237
# 106 .. 237
# 105 .. 237
# 106 .. 237
# 105 .. 237
# 106 .. 237
# 106 .. 237
# 105 .. 237
# 105 .. 237
# 105 .. 237
#        ...
# 106 .. 237
# 105 .. 237
# 105 .. 237
# 105 .. 237
# 105 .. 237
# 105 .. 237
# 105 .. 237
# 105 .. 237
# 105 .. 237
# 105 .. 237
# 105 .. 237
# 105 .. 237

# %% [markdown]
# ### Pkg_1

# %%
plt.figure(dpi=144)
plt.imshow(data['Pkg_1'][:200,:].T)
plt.figure(dpi=144)
plt.imshow(data['Pkg_1'][200:400,:].T)

# %% [markdown]
# ### PKg_2

# %%
plt.figure(dpi=144)
plt.imshow(data['Pkg_2'][:200,:].T)
plt.figure(dpi=144)
plt.imshow(data['Pkg_2'][200:400,:].T)
